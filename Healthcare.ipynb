# %%
import pandas as pd
from pandas import DataFrame as df
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'datasets/GLLRSLHealthCareSystemPublic.xlsx'
#'datasets/health-care-workers-evd.xlsx' I think this dataset is not good

# %%
excel_book = xlrd.open_workbook(filename)
excel_book.sheet_names()
# Out:
# [u'Disclaimers',
#  u'Guinea Health Facilities',
#  u'Liberia Health Facilities',
#  u'Sierra Leone Health Facilities',
#  u'Mali CSCOM-CSREF',
#  u'Information sources',
#  u'Articles',
#  u'Copy of Oct 31 SLR Health Cente']

# %%
ebola_time_series = pd.read_excel(filename,1)

# %%
ebola_time_series.head(10)
# Out:
#     Country   Status     Verified                 Date Center ID  \
# 0  #country  #status  #x_verified         #report_date   #loc_id
# 1    Guinea      NaN            Y  2002-01-01 00:00:00    HM0096
# 2    Guinea     Open            Y  2014-10-09 00:00:00    MOH035
# 3    Guinea      NaN            Y  2002-01-01 00:00:00    HM0097
# 4    Guinea      NaN            N  2002-01-01 00:00:00    HM0933
# 5    Guinea      NaN            Y  2002-01-01 00:00:00    HM0098
# 6    Guinea      NaN            N  2002-01-01 00:00:00    HM0099
# 7    Guinea      NaN            Y  2002-01-01 00:00:00    HM0101
# 8    Guinea      NaN            Y  2002-01-01 00:00:00    HM0100
# 9    Guinea      NaN            Y  2002-01-01 00:00:00    HM0102
#
#                          Center           Type   Activity   Org Capacity (N)  \
# 0                          #loc       #loctype  #activity  #org  #x_capacity
# 1      Hopital Préfectoal Boffa   Hospital (1)        NaN   GOV          NaN
# 2  Centre de Santé Boffa Centre            CSU        NaN   GOV          NaN
# 3                       Bolonde              3        NaN   GOV          NaN
# 4                           NaN              4        NaN   GOV          NaN
# 5                       Lakhata              4        NaN   GOV          NaN
# 6                       Lonking              4        NaN   GOV          NaN
# 7                       Douprou  Health Center        NaN   GOV          NaN
# 8                      Koumbaya              4        NaN   GOV          NaN
# 9                      Bilnsadé              4        NaN   GOV          NaN
#
#       ...      Sous Prefecture      Adm3 ID           Place         Lat  \
# 0     ...                #adm3     #adm3_id    #x_placename    #lat_deg
# 1     ...         Boffa Centre  GIN00100101           Boffa  10.1787004
# 2     ...         Boffa centre  GIN00100101    Boffa centre     10.1812
# 3     ...         Boffa Centre  GIN00100101         Bolonde  10.1829004
# 4     ...         Boffa Centre  GIN00100101         Dembaya  10.0275002
# 5     ...         Boffa Centre  GIN00100101         Lakhata   10.234334
# 6     ...         Boffa Centre  GIN00100101         Lonking  10.2918997
# 7     ...              Douprou  GIN00100102  Douprou Centre     10.2423
# 8     ...              Douprou  GIN00100102       Koundinde   10.267259
# 9     ...              Douprou  GIN00100102         Sobanet  10.2531004
#
#           Long       Address Clinic Website Location in OSM  \
# 0     #lon_deg      #address      #site_lnk      #x_loc_osm
# 1  -14.0310001    CS Bolondè            NaN             NaN
# 2     -14.0377  Boffa centre            NaN             NaN
# 3     -14.0414           NaN            NaN             NaN
# 4  -13.8823996           NaN            NaN             NaN
# 5   -14.221820           NaN            NaN             NaN
# 6  -14.0120001           NaN            NaN             NaN
# 7  -14.3375998           NaN            NaN             NaN
# 8   -14.425758           NaN            NaN             NaN
# 9  -14.3971004           NaN            NaN             NaN
#
#                                                Notes  \
# 0                                           #x_notes
# 1                                                NaN
# 2  Lat/long at center of Boffa village , Polliing...
# 3                                                NaN
# 4  There are several locations in Guinea with the...
# 5                                                NaN
# 6  This is geolocated to an unlisted village outs...
# 7                                                NaN
# 8                                                NaN
# 9         geoloc to village level - cannot find name
#
#                                       Source of info
# 0                                          #data_lnk
# 1                                                NaN
# 2  MOH. http://www.ceniguinee.org/doc/bv_pdf/List...
# 3                                                NaN
# 4  https://www.google.com.sl/maps/place/Boffa,+Gu...
# 5                                                NaN
# 6  https://www.google.com.sl/maps/place/10%C2%B01...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 36 columns]
