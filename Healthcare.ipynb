# %%
import pandas as pd
from pandas import DataFrame as df
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/sabina/anaconda/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
filename = 'datasets/sierra-leone-health-centers-141111.xlsx'
#'datasets/health-care-workers-evd.xlsx' I think this dataset is not good

# %%
excel_book = xlrd.open_workbook(filename)
excel_book.sheet_names()
# Out:
# [u'Disclaimers',
#  u'Sierra Leone Health Facilities',
#  u'Information sources',
#  u'Articles']

# %%
ebola_time_series = pd.read_excel(filename,1)

# %%
ebola_time_series.head(10)
# Out:
#         Country      Status     Verified                 Date Centre ID  \
# 0      #country     #status  #x_verified         #report_date   #loc_id
# 1  Sierra Leone  Functional          NaN  2014-09-17 00:00:00    HF1227
# 2  Sierra Leone        Open            Y  2014-09-17 00:00:00    HF1228
# 3  Sierra Leone  Functional            Y  2014-09-17 00:00:00    HF1229
# 4  Sierra Leone         NaN          NaN                  NaN    HF1230
# 5  Sierra Leone         NaN          NaN                  NaN    HF1231
# 6  Sierra Leone         NaN          NaN                  NaN    HF1232
# 7  Sierra Leone         NaN          NaN                  NaN    HF1233
# 8  Sierra Leone        Open          Yes  2012-01-01 00:00:00    HF0001
# 9  Sierra Leone        Open      Y- Greg  2012-01-01 00:00:00    HF0003
#
#                              Center           Type     Activity   Org  \
# 0                              #loc       #loctype    #activity  #org
# ...
